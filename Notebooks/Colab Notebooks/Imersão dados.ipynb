# %% [markdown]
# **Aula 1**

# %% [markdown]
# Importar a base de dados utilizando a biblioteca pandas extraíndo dados de um .zip

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'
dados = pd.read_csv(url_dados, compression='zip')

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
dados['tratamento'].value_counts().plot.bar().legend()

# %%
dados_com_droga = dados[dados['tratamento']=='com_droga']
dados_sem_droga= dados[dados['tratamento']=='com_controle']

dados_com_droga['droga'].value_counts(normalize=True)
# Out:
# 87d714366    0.032714
# 9f80f3f77    0.011208
# 8b87a7a83    0.009249
# 5628cb3ee    0.009204
# d08af5d4b    0.008930
#                ...
# b046f598b    0.000046
# 379302187    0.000046
# b9ffc9444    0.000046
# 1d39c75d6    0.000046
# 44bba684f    0.000046
# Name: droga, Length: 3288, dtype: float64

# %%
dados_sem_droga['droga'].value_counts(normalize=True)
# Out:
# cacb2b860    1.0
# Name: droga, dtype: float64

# %% [markdown]
# ### Desafio 1: Investigar por que a classe tratamento é tão desbalanceada?
#
# Porque existem vários tipos de drogas testadas (3289 códigos).
# O grupo controle utilizou a droga 'cacb2b860'
#
# ### Desafio 3: Proporção das classes tratamento.
#
# ### Desafio 4: Quantos tipos de drogas foram investigados?
#
# ### Desafio 5: Procurar na documentação o método query(pandas).
#
# ### Desafio 6: Renomear as colunas tirando o hífen.
#
# ### Desafio 7: Deixar os gráficos mais apresentáveis (com títulos e legendas).
#
# ### Desafio 8: Resumo do que aprendeu.

# %% [markdown]
# #Desafio 2: Plotar as 5 últimas linhas da tabela.

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10,8))

ax=sns.countplot(x='composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')
plt.show()

# %%
dados['g-0'].hist(bins=150)

# %%
dados.loc[:,'c-0':'c-99']
# Out:
#           c-0     c-1     c-2     c-3  ...    c-96    c-97    c-98    c-99
# 0     -0.0600  0.1083  0.6864  0.4043  ... -0.3981  0.2139  0.3801  0.4176
# 1      0.0927  0.2723  0.2772  0.7776  ...  0.1522  0.1241  0.6077  0.7371
# 2     -0.1312 -1.4640  0.3394 -1.7790  ... -0.6417 -0.2187 -1.4080  0.6931
# 3     -0.3998 -4.5520 -2.7350 -1.9630  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4     -0.3774  0.7364 -0.1659  0.2341  ...  0.1094  0.2885 -0.3786  0.7125
# ...       ...     ...     ...     ...  ...     ...     ...     ...     ...
# 23809  0.4224  0.1871 -0.4822  0.3713  ...  0.0631  0.9171  0.5258  0.4680
# 23810  0.2144  0.4350  0.1174  1.3960  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  1.0650  0.6329  0.3742  0.1237  ...  0.2256  0.7592  0.6656  0.3808
# 23812  0.5377  1.3240  0.9679  0.1419  ...  0.1732  0.7015 -0.6290  0.0740
# 23813 -2.3890 -2.0350 -1.1080 -6.2650  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 100 columns]

# %%
### Faz uma descrição estatística dos dados pegando apenas os valores cs
dados.loc[:,'c-0':'c-99'].describe().T['mean'].hist(bins=50)

# %%
sns.boxplot(x='tratamento',y='g-0',data=dados)

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# tempo    24    48    72
# dose
# D1     3886  4354  3907
# D2     3886  3896  3885

# %%
pd.crosstab([dados['dose'], dados['tempo']],dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']],dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
pd.crosstab([dados['dose'], dados['tempo']],dados['tratamento'], values=dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
dados.loc[:,'g-0':'c-99'].corr()
# Out:
#            g-0       g-1       g-2  ...      c-97      c-98      c-99
# g-0   1.000000  0.086032  0.176188  ... -0.622840 -0.640484 -0.609238
# g-1   0.086032  1.000000 -0.054518  ... -0.008487 -0.002824 -0.002308
# g-2   0.176188 -0.054518  1.000000  ... -0.178812 -0.170152 -0.172124
# g-3   0.011266 -0.027855  0.042633  ... -0.049951 -0.079855 -0.037579
# g-4   0.403153  0.193647  0.013968  ... -0.394904 -0.366693 -0.390581
# ...        ...       ...       ...  ...       ...       ...       ...
# c-95 -0.600758 -0.011237 -0.158105  ...  0.811155  0.787529  0.758110
# c-96 -0.646784 -0.022127 -0.182540  ...  0.863061  0.819600  0.789649
# c-97 -0.622840 -0.008487 -0.178812  ...  1.000000  0.801809  0.775300
# c-98 -0.640484 -0.002824 -0.170152  ...  0.801809  1.000000  0.755991
# c-99 -0.609238 -0.002308 -0.172124  ...  0.775300  0.755991  1.000000
#
# [872 rows x 872 columns]

# %%
sns.lmplot(data=dados, x='g-0', y='c-0', line_kws={'color': 'red'}, col='tratamento', row='tempo')

# %% [markdown]
# ### Aula 04
